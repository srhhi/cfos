# %% [markdown]
# ### Introduction
# Kaggle Amazon Consumer Behaviour available in: https://www.kaggle.com/datasets/swathiunnikrishnan/amazon-consumer-behaviour-dataset
#
#
# ### Data description
# Below are the description of the features/columns in the data:
#
# <ol>
#     <li>age: age</li>
#     <li>gender: gender</li>
#     <li>Purchase_Frequency: How frequently do you make purchases on Amazon?</li>
#     <li>Purchase_Categories: What product categories do you typically purchase on Amazon?</li>
#     <li>Personalized_Recommendation_Frequency: Have you ever made a purchase based on personalized product recommendations from Amazon?</li>
#     <li>Browsing_Frequency: How often do you browse Amazon's website or app?</li>
#     <li>Product_Search_Method: How do you search for products on Amazon?</li>
#     <li>Search_Result_Exploration: Do you tend to explore multiple pages of search results or focus on the first page?</li>
#     <li>Customer_Reviews_Importance: How important are customer reviews in your decision-making process?</li>
#     <li>Add_to_Cart_Browsing: Do you add products to your cart while browsing on Amazon?</li>
#     <li>Cart_Completion_Frequency: How often do you complete the purchase after adding products to your cart?</li>
#     <li>Cart_Abandonment_Factors: What factors influence your decision to abandon a purchase in your cart?</li>
#     <li>Saveforlater_Frequency: Do you use Amazon's "Save for Later" feature, and if so, how often?</li>
#     <li>Review_Left: Have you ever left a product review on Amazon?</li>
#     <li>Review_Reliability: How much do you rely on product reviews when making a purchase?</li>
#     <li>Review_Helpfulness: Do you find helpful information from other customers' reviews?</li>
#     <li>Personalized_Recommendation_Frequency: How often do you receive personalized product recommendations from Amazon?</li>
#     <li>Recommendation_Helpfulness: Do you find the recommendations helpful?</li>
#     <li>Rating_Accuracy: How would you rate the relevance and accuracy of the recommendations you receive</li>
#     <li>Shopping_Satisfaction: How satisfied are you with your overall shopping experience on Amazon?</li>
#     <li>Service_Appreciation: What aspects of Amazon's services do you appreciate the most?</li>
#     <li>Improvement_Areas: Are there any areas where you think Amazon can improve?</li>
# </ol>

# %% [markdown]
# ## 1. Import relevant python libraries.

# %%
# import required packages for EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
from collections import Counter
# %matplotlib inline
# Out:
# C:\Users\srhhi\anaconda3\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.5)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## 2. Load the data into the dataframe. Place the dataset in the default jupyter notebook folder (.csv file).

# %%
# Load data into data frame using pandas package - we'll be using the Amazon Customer Behaviour Survey.csv.
amazon_df = pd.read_csv('Amazon Customer Behavior Survey.csv')

# %%
# Display the data - first five & last five. Has 602 rows & 24 columns.
amazon_df
# Out:
#                           Timestamp  age             Gender  \
# 0    2023/06/04 1:28:19 PM GMT+5:30   23             Female
# 1    2023/06/04 2:30:44 PM GMT+5:30   23             Female
# 2    2023/06/04 5:04:56 PM GMT+5:30   24  Prefer not to say
# 3    2023/06/04 5:13:00 PM GMT+5:30   24             Female
# 4    2023/06/04 5:28:06 PM GMT+5:30   22             Female
# ..                              ...  ...                ...
# 597  2023/06/12 4:02:02 PM GMT+5:30   23             Female
# 598  2023/06/12 4:02:53 PM GMT+5:30   23             Female
# 599  2023/06/12 4:03:59 PM GMT+5:30   23             Female
# 600  2023/06/12 9:57:20 PM GMT+5:30   23             Female
# 601  2023/06/16 9:16:05 AM GMT+5:30   23             Female
#
#          Purchase_Frequency  \
# 0         Few times a month
# 1              Once a month
# 2         Few times a month
# 3              Once a month
# 4    Less than once a month
# ..                      ...
# 597             Once a week
# ...

# %%
# Displaying first five data.
amazon_df.head()
# Out:
#                         Timestamp  age             Gender  \
# 0  2023/06/04 1:28:19 PM GMT+5:30   23             Female
# 1  2023/06/04 2:30:44 PM GMT+5:30   23             Female
# 2  2023/06/04 5:04:56 PM GMT+5:30   24  Prefer not to say
# 3  2023/06/04 5:13:00 PM GMT+5:30   24             Female
# 4  2023/06/04 5:28:06 PM GMT+5:30   22             Female
#
#        Purchase_Frequency                                Purchase_Categories  \
# 0       Few times a month                           Beauty and Personal Care
# 1            Once a month                               Clothing and Fashion
# 2       Few times a month    Groceries and Gourmet Food;Clothing and Fashion
# 3            Once a month  Beauty and Personal Care;Clothing and Fashion;...
# 4  Less than once a month      Beauty and Personal Care;Clothing and Fashion
#
#   Personalized_Recommendation_Frequency Browsing_Frequency  \
# 0                                   Yes   Few times a week
# ...

# %%
# Display last five record in dataframe
amazon_df.tail()
# Out:
#                           Timestamp  age  Gender Purchase_Frequency  \
# 597  2023/06/12 4:02:02 PM GMT+5:30   23  Female        Once a week
# 598  2023/06/12 4:02:53 PM GMT+5:30   23  Female        Once a week
# 599  2023/06/12 4:03:59 PM GMT+5:30   23  Female       Once a month
# 600  2023/06/12 9:57:20 PM GMT+5:30   23  Female  Few times a month
# 601  2023/06/16 9:16:05 AM GMT+5:30   23  Female        Once a week
#
#                                    Purchase_Categories  \
# 597                           Beauty and Personal Care
# 598                               Clothing and Fashion
# 599                           Beauty and Personal Care
# 600  Beauty and Personal Care;Clothing and Fashion;...
# 601                               Clothing and Fashion
#
#     Personalized_Recommendation_Frequency    Browsing_Frequency  \
# 597                             Sometimes      Few times a week
# 598                             Sometimes      Few times a week
# ...

# %%
# Set the name of the columns to all lowercase
amazon_df.columns = map(str.lower, amazon_df.columns)

# %%
# Calling the shape attribute of the amazon dataset we can observe that there are 602 observations/rows and 23 features/columns
# in the data set
print ("Dataset shape: ", amazon_df.shape)
# Out:
# Dataset shape:  (602, 23)

# %%
#Display the column/feature names available in amazon_df.
# Print the column/feature names
print(amazon_df.columns.values)
# Out:
# ['timestamp' 'age' 'gender' 'purchase_frequency' 'purchase_categories'
#  'personalized_recommendation_frequency' 'browsing_frequency'
#  'product_search_method' 'search_result_exploration'
#  'customer_reviews_importance' 'add_to_cart_browsing'
#  'cart_completion_frequency' 'cart_abandonment_factors'
#  'saveforlater_frequency' 'review_left' 'review_reliability'
#  'review_helpfulness' 'personalized_recommendation_scale'
#  'recommendation_helpfulness' 'rating_accuracy ' 'shopping_satisfaction'
#  'service_appreciation' 'improvement_areas']

# %% [markdown]
# ### Data types, missing data and summary statistics

# %%
# Non-null count and data types of the dataset.
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   timestamp                              602 non-null    object
#  1   age                                    602 non-null    int64
#  2   gender                                 602 non-null    object
#  3   purchase_frequency                     602 non-null    object
#  4   purchase_categories                    602 non-null    object
#  5   personalized_recommendation_frequency  602 non-null    object
#  6   browsing_frequency                     602 non-null    object
#  7   product_search_method                  600 non-null    object
#  8   search_result_exploration              602 non-null    object
#  9   customer_reviews_importance            602 non-null    int64
# ...

# %%
# Missing data in amazon dataset by columns
amazon_df.isnull().sum().sort_values(ascending = False)
# Out:
# product_search_method                    2
# timestamp                                0
# cart_abandonment_factors                 0
# service_appreciation                     0
# shopping_satisfaction                    0
# rating_accuracy                          0
# recommendation_helpfulness               0
# personalized_recommendation_scale        0
# review_helpfulness                       0
# review_reliability                       0
# review_left                              0
# saveforlater_frequency                   0
# cart_completion_frequency                0
# age                                      0
# add_to_cart_browsing                     0
# customer_reviews_importance              0
# search_result_exploration                0
# browsing_frequency                       0
# personalized_recommendation_frequency    0
# purchase_categories                      0
# purchase_frequency                       0
# gender                                   0
# ...

# %%
# Missing data in amazon dataset
missingno.matrix(amazon_df)
# Out:
# <AxesSubplot:>

# %%
# Display the overall descriptive statistics of the data we got to get the overall idea of what kind of data we are using.
amazon_df.describe()
# Out:
#               age  customer_reviews_importance  \
# count  602.000000                   602.000000
# mean    30.790698                     2.480066
# std     10.193276                     1.185226
# min      3.000000                     1.000000
# 25%     23.000000                     1.000000
# 50%     26.000000                     3.000000
# 75%     36.000000                     3.000000
# max     67.000000                     5.000000
#
#        personalized_recommendation_scale  rating_accuracy   \
# count                         602.000000        602.000000
# mean                            2.699336          2.672757
# std                             1.042028          0.899744
# min                             1.000000          1.000000
# 25%                             2.000000          2.000000
# 50%                             3.000000          3.000000
# 75%                             3.000000          3.000000
# max                             5.000000          5.000000
#
# ...

# %% [markdown]
# ### Numerical variables
# Numerical variables in amazon dataset are Age, Customer Review Importance, Personalized Recommendation Frequency, Rating Accuracy and Shopping Satisfaction.
#
# ### Detect and remove outliers in numerical variables - you may do this during data cleaning
# <ul>
#     <li>Outliers are data points that have extreme values and they do not conform with the majority of the data.</li>
#     <li>It is important to address this because outliers tend to skew our data towards extremes and can cause inaccurate model predictions.</li>
#     <li>We will use the Tukey method to remove these outliers.</li>
# </ul>
#
# #### This function will loop through a list of features and detect outliers in each one of those features
#
# 1- In each loop, a data point is deemed an outlier if it is less than the first quartile minus the outlier step or exceeds
#
# 2- third quartile plus the outlier step. The outlier step is defined as 1.5 times the interquartile range.
#
# 3- Once the outliers have been determined for one feature, their indices will be stored in a list before proceeding to the next feature and the process repeats until the very last feature is completed.
#
# 4- Finally, using the list with outlier indices, we will count the frequencies of the index numbers and return them if their frequency exceeds n times.

# %%
def detect_outliers(df, n, features):
   
    outlier_indices = [] 
    for col in features: 
        Q1 = np.percentile(df[col], 25)
        Q3 = np.percentile(df[col], 75)
        IQR = Q3 - Q1
        outlier_step = 1.5 * IQR 
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step)].index
        outlier_indices.extend(outlier_list_col) 
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(key for key, value in outlier_indices.items() if value > n) 
    return multiple_outliers

outliers_to_drop = detect_outliers(amazon_df, 2, ['age'])
print("We will drop these {} indices: ".format(len(outliers_to_drop)), outliers_to_drop)
# Out:
# We will drop these 0 indices:  []

# %%
# List out outliers in numerical variables (10 observations/rows) - Age
amazon_df.loc[outliers_to_drop, :]
# Out:
# Empty DataFrame
# Columns: [timestamp, age, gender, purchase_frequency, purchase_categories, personalized_recommendation_frequency, browsing_frequency, product_search_method, search_result_exploration, customer_reviews_importance, add_to_cart_browsing, cart_completion_frequency, cart_abandonment_factors, saveforlater_frequency, review_left, review_reliability, review_helpfulness, personalized_recommendation_scale, recommendation_helpfulness, rating_accuracy , shopping_satisfaction, service_appreciation, improvement_areas]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Drop outliers and reset index
print("Before: {} rows".format(len(amazon_df)))
amazon_df = amazon_df.drop(outliers_to_drop, axis = 0).reset_index(drop = True)
print("After: {} rows".format(len(amazon_df)))
# Out:
# Before: 602 rows
# After: 602 rows

# %% [markdown]
# ### Numerical variable: Age

# %%
# Null values in Age column - use sum because its in a distributed across wide range of values, found 0 missing values.
amazon_df['age'].isnull().sum()
# Out:
# 0

# %%
# Value count is not an appropriate measure to analyze the age since its distributed across wide range of ages.
# Using displot to visualize the age distribution
sns.displot(amazon_df['age'], label = 'Skewness: %.2f'%(amazon_df['age'].skew()))
plt.legend(loc = 'best')
plt.title('Amazon Age Distribution')
# Out:
# Text(0.5, 1.0, 'Amazon Age Distribution')

# %% [markdown]
# ### Data Cleaning
#
# Drop Timestamp column for simplicity of this tutorial. Replace the null values with appropriate values.
#
# Having missing values in a dataset can cause errors with some machine learning algorithms and either the rows that has missing values should be removed or imputed.
#
# Imputing: using a model to replace missing values.
#
# There are many options we could consider when replacing a missing value, for example:
#
# <ul>
#     <li>constant value that has meaning within the domain, such as 0, distinct from all other values.</li>
#     <li>value from another randomly selected record.</li>
#     <li>mean, median or mode value for the column.</li>
#     <li>value estimated by another predictive model.</li>
# </ul>
#
# As an example, if the value only has few categories (e.g., Embarked), you may replace them with mode value (most frequently occuring value), or if the values span across wide range of values (e.g., Age/Fare) then you may use median (central number of the dataset) or mean (average value of the dataset).

# %%
# Drop Timestamp column as they are not relevent in this analysis - for simplicity.
amazon_df = amazon_df.drop(['timestamp'], axis = 1)

# Recheck dropped columns
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   age                                    602 non-null    int64
#  1   gender                                 602 non-null    object
#  2   purchase_frequency                     602 non-null    object
#  3   purchase_categories                    602 non-null    object
#  4   personalized_recommendation_frequency  602 non-null    object
#  5   browsing_frequency                     602 non-null    object
#  6   product_search_method                  600 non-null    object
#  7   search_result_exploration              602 non-null    object
#  8   customer_reviews_importance            602 non-null    int64
#  9   add_to_cart_browsing                   602 non-null    object
# ...

# %%
# we see that there are illogical values in age
# since it is impossible for 3 year old customer to purchase a product
print((amazon_df.age < 10).sum())
# Out:
# 1

# %%
# drop value that do not satisfy logical condition
amazon_df.drop(amazon_df[amazon_df['age'] < 10].index, inplace = True)

# Recheck the value again if there is any illogical value in Age
print((amazon_df['age'] < 10).sum())
# Out:
# 0

# %%
# Overall missing values in the data frame - Got 2 missing values in Product Search Method
amazon_df.isnull().sum().sort_values(ascending = False)
# Out:
# product_search_method                    2
# age                                      0
# saveforlater_frequency                   0
# service_appreciation                     0
# shopping_satisfaction                    0
# rating_accuracy                          0
# recommendation_helpfulness               0
# personalized_recommendation_scale        0
# review_helpfulness                       0
# review_reliability                       0
# review_left                              0
# cart_abandonment_factors                 0
# gender                                   0
# cart_completion_frequency                0
# add_to_cart_browsing                     0
# customer_reviews_importance              0
# search_result_exploration                0
# browsing_frequency                       0
# personalized_recommendation_frequency    0
# purchase_categories                      0
# purchase_frequency                       0
# improvement_areas                        0
# ...

# %%
# Replacing the Product Search Method with mode (the most frequently occuring) value
# Compute the most frequent value of Product Search Method in amazon dataset
mode = amazon_df['product_search_method'].dropna().mode()[0]
mode
# Out:
# 'categories'

# %%
# Fill missing value in Product Search Method with mode = 'categories'
amazon_df['product_search_method'].fillna(mode, inplace = True)
amazon_df.isnull().sum().sort_values(ascending = False)
# Out:
# age                                      0
# gender                                   0
# service_appreciation                     0
# shopping_satisfaction                    0
# rating_accuracy                          0
# recommendation_helpfulness               0
# personalized_recommendation_scale        0
# review_helpfulness                       0
# review_reliability                       0
# review_left                              0
# saveforlater_frequency                   0
# cart_abandonment_factors                 0
# cart_completion_frequency                0
# add_to_cart_browsing                     0
# customer_reviews_importance              0
# search_result_exploration                0
# product_search_method                    0
# browsing_frequency                       0
# personalized_recommendation_frequency    0
# purchase_categories                      0
# purchase_frequency                       0
# improvement_areas                        0
# ...

# %%
# Create new column of Polarity shopping satisfaction - Assign whether the rating was either Positive/Neutral/Negative
# 4-5 - Positive, 3 - Neutral, 1-2 - Negative
amazon_df['polarity_shopping_satisfaction'] = amazon_df['shopping_satisfaction'].apply(lambda x: 'Positive' if x > 3 
                                                                            else('Neutral' if x == 3 else 'Negative'))
# Check the newly added Polarity Shopping Satisfaction
amazon_df.head()
# Out:
#    age             gender      purchase_frequency  \
# 0   23             Female       Few times a month
# 1   23             Female            Once a month
# 2   24  Prefer not to say       Few times a month
# 3   24             Female            Once a month
# 4   22             Female  Less than once a month
#
#                                  purchase_categories  \
# 0                           Beauty and Personal Care
# 1                               Clothing and Fashion
# 2    Groceries and Gourmet Food;Clothing and Fashion
# 3  Beauty and Personal Care;Clothing and Fashion;...
# 4      Beauty and Personal Care;Clothing and Fashion
#
#   personalized_recommendation_frequency browsing_frequency  \
# 0                                   Yes   Few times a week
# 1                                   Yes  Few times a month
# 2                                    No  Few times a month
# 3                             Sometimes  Few times a month
# ...

# %%
# Create a dataframe for each of the polarity shopping satisfaction
df_Positive = amazon_df[amazon_df['polarity_shopping_satisfaction'] == 'Positive']
df_Neutral = amazon_df[amazon_df['polarity_shopping_satisfaction'] == 'Neutral']
df_Negative = amazon_df[amazon_df['polarity_shopping_satisfaction'] == 'Negative']

print ("df_Positive shape: ", df_Positive.shape)
print ("df_Neutral shape: ", df_Neutral.shape)
print ("df_Negative shape: ", df_Negative.shape)
# Out:
# df_Positive shape:  (84, 23)
# df_Neutral shape:  (209, 23)
# df_Negative shape:  (308, 23)

# %%
#splitting age into different catogories
bins = [0, 20, 30, 40, 50, float('inf')]
labels = ['15-25', '25-35', '35-45', '45-55', '55+']

# Create a new column 'Age Category' with the grouped age categories
amazon_df['age_category'] = pd.cut(amazon_df['age'], bins=bins, labels=labels, right=False)

# Check the newly added Age Category
amazon_df.head()
# Out:
#    age             gender      purchase_frequency  \
# 0   23             Female       Few times a month
# 1   23             Female            Once a month
# 2   24  Prefer not to say       Few times a month
# 3   24             Female            Once a month
# 4   22             Female  Less than once a month
#
#                                  purchase_categories  \
# 0                           Beauty and Personal Care
# 1                               Clothing and Fashion
# 2    Groceries and Gourmet Food;Clothing and Fashion
# 3  Beauty and Personal Care;Clothing and Fashion;...
# 4      Beauty and Personal Care;Clothing and Fashion
#
#   personalized_recommendation_frequency browsing_frequency  \
# 0                                   Yes   Few times a week
# 1                                   Yes  Few times a month
# 2                                    No  Few times a month
# 3                             Sometimes  Few times a month
# ...

# %%
# Use str.split() to split a column to a list
amazon_df["purchase_categories"] = amazon_df["purchase_categories"].str.split(";")

# Convert the column with a list-type value to multiple rows
amazon_df = amazon_df.explode("purchase_categories")

amazon_df.head()
# Out:
#    age             gender purchase_frequency         purchase_categories  \
# 0   23             Female  Few times a month    Beauty and Personal Care
# 1   23             Female       Once a month        Clothing and Fashion
# 2   24  Prefer not to say  Few times a month  Groceries and Gourmet Food
# 2   24  Prefer not to say  Few times a month        Clothing and Fashion
# 3   24             Female       Once a month    Beauty and Personal Care
#
#   personalized_recommendation_frequency browsing_frequency  \
# 0                                   Yes   Few times a week
# 1                                   Yes  Few times a month
# 2                                    No  Few times a month
# 2                                    No  Few times a month
# 3                             Sometimes  Few times a month
#
#   product_search_method search_result_exploration  \
# 0               Keyword            Multiple pages
# 1               Keyword            Multiple pages
# ...

# %%
## Display the count of each columns based on Purchase Categories. 
amazon_df.groupby(by=["purchase_categories"], dropna=False).count()
# Out:
#                             age  gender  purchase_frequency  \
# purchase_categories
# Beauty and Personal Care    318     318                 318
# Clothing and Fashion        343     343                 343
# Groceries and Gourmet Food  111     111                 111
# Home and Kitchen            219     219                 219
# others                      166     166                 166
#
#                             personalized_recommendation_frequency  \
# purchase_categories
# Beauty and Personal Care                                      318
# Clothing and Fashion                                          343
# Groceries and Gourmet Food                                    111
# Home and Kitchen                                              219
# others                                                        166
#
#                             browsing_frequency  product_search_method  \
# purchase_categories
# ...

# %%
# Informational purposes: Display basic statistics of dataset in general.
# Display some basic statistic of the dataset.
print('\033[1m' + 'Basic Statistic (World)' + '\033[0m')
print('_'*50)
print('Number of Gender:', amazon_df["gender"].nunique(), "Unique Gender")
print('Number of Purchase Category:', amazon_df["purchase_categories"].nunique(), "Unique Purchase Categories")
# Out:
# Basic Statistic (World)
# __________________________________________________
# Number of Gender: 4 Unique Gender
# Number of Purchase Category: 5 Unique Purchase Categories

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1157 entries, 0 to 601
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   age                                    1157 non-null   int64
#  1   gender                                 1157 non-null   object
#  2   purchase_frequency                     1157 non-null   object
#  3   purchase_categories                    1157 non-null   object
#  4   personalized_recommendation_frequency  1157 non-null   object
#  5   browsing_frequency                     1157 non-null   object
#  6   product_search_method                  1157 non-null   object
#  7   search_result_exploration              1157 non-null   object
#  8   customer_reviews_importance            1157 non-null   int64
#  9   add_to_cart_browsing                   1157 non-null   object
# ...

# %%
# Saving the new dataset into a csv file
amazon_df.to_csv("cleaned_amazon.csv")
